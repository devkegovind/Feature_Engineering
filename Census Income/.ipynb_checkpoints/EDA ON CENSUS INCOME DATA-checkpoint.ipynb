# %% [markdown]
# <h1 align='center'>EDA ON CENSUS INCOME DATA</h1>

# %% [markdown]
# #### Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# #### Import Dataset

# %%
df = pd.read_csv("adult_data.csv", sep=",")
df
# Out:
#        Sr.No.           Job_Type  Emp_Id    Education  Exp  \
# 0          39          State-gov   77516    Bachelors   13
# 1          50   Self-emp-not-inc   83311    Bachelors   13
# 2          38            Private  215646      HS-grad    9
# 3          53            Private  234721         11th    7
# 4          28            Private  338409    Bachelors   13
# ...       ...                ...     ...          ...  ...
# 32556      27            Private  257302   Assoc-acdm   12
# 32557      40            Private  154374      HS-grad    9
# 32558      58            Private  151910      HS-grad    9
# 32559      22            Private  201490      HS-grad    9
# 32560      52       Self-emp-inc  287927      HS-grad    9
#
#                     Status                Role     Living_with  Colour  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# #### Copy the Dataframe

# %%
df1 = df.copy()
df1
# Out:
#        Sr.No.           Job_Type  Emp_Id    Education  Exp  \
# 0          39          State-gov   77516    Bachelors   13
# 1          50   Self-emp-not-inc   83311    Bachelors   13
# 2          38            Private  215646      HS-grad    9
# 3          53            Private  234721         11th    7
# 4          28            Private  338409    Bachelors   13
# ...       ...                ...     ...          ...  ...
# 32556      27            Private  257302   Assoc-acdm   12
# 32557      40            Private  154374      HS-grad    9
# 32558      58            Private  151910      HS-grad    9
# 32559      22            Private  201490      HS-grad    9
# 32560      52       Self-emp-inc  287927      HS-grad    9
#
#                     Status                Role     Living_with  Colour  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# #### Fetch the First Five Records From the Dataframe

# %%
df1.head()
# Out:
#    Sr.No.           Job_Type  Emp_Id   Education  Exp               Status  \
# 0      39          State-gov   77516   Bachelors   13        Never-married
# 1      50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 2      38            Private  215646     HS-grad    9             Divorced
# 3      53            Private  234721        11th    7   Married-civ-spouse
# 4      28            Private  338409   Bachelors   13   Married-civ-spouse
#
#                  Role     Living_with  Colour      Sex   HRA  TA  DA  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#           Country  Salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# ...

# %% [markdown]
# #### Check the Size of Dataframe

# %%
df1.shape
# Out:
# (32561, 15)

# %% [markdown]
# #### Fetch the Last Five Records From the Dataframe

# %%
df1.tail()
# Out:
#        Sr.No.       Job_Type  Emp_Id    Education  Exp               Status  \
# 32556      27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32557      40        Private  154374      HS-grad    9   Married-civ-spouse
# 32558      58        Private  151910      HS-grad    9              Widowed
# 32559      22        Private  201490      HS-grad    9        Never-married
# 32560      52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#                      Role Living_with  Colour      Sex    HRA  TA  DA  \
# 32556        Tech-support        Wife   White   Female      0   0  38
# 32557   Machine-op-inspct     Husband   White     Male      0   0  40
# 32558        Adm-clerical   Unmarried   White   Female      0   0  40
# 32559        Adm-clerical   Own-child   White     Male      0   0  20
# 32560     Exec-managerial        Wife   White   Female  15024   0  40
#
#               Country  Salary
# 32556   United-States   <=50K
# ...

# %% [markdown]
# #### Fetch the Sample Record From the Dataframe

# %%
df1.sample()
# Out:
#        Sr.No.  Job_Type  Emp_Id Education  Exp     Status    Role Living_with  \
# 22624      29   Private  163167   HS-grad    9   Divorced   Sales   Own-child
#
#        Colour    Sex  HRA  TA  DA         Country  Salary
# 22624   White   Male    0   0  40   United-States   <=50K

# %% [markdown]
# #### Fetch the Information of Dataframe

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       32561 non-null  int64
#  1   Job_Type     32561 non-null  object
#  2   Emp_Id       32561 non-null  int64
#  3   Education    32561 non-null  object
#  4   Exp          32561 non-null  int64
#  5   Status       32561 non-null  object
#  6   Role         32561 non-null  object
#  7   Living_with  32561 non-null  object
#  8   Colour       32561 non-null  object
#  9   Sex          32561 non-null  object
#  10  HRA          32561 non-null  int64
#  11  TA           32561 non-null  int64
#  12  DA           32561 non-null  int64
#  13  Country      32561 non-null  object
#  14  Salary       32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# #### Fetch the Statistical Information of Dataframe

# %% [markdown]
# ##### Fetch the Statistical Information of Dataframe contain only Numerical Features

# %%
df1.describe()
# Out:
#              Sr.No.        Emp_Id           Exp           HRA            TA  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                  DA
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
df1.describe().T
# Out:
#           count           mean            std      min       25%       50%  \
# Sr.No.  32561.0      38.581647      13.640433     17.0      28.0      37.0
# Emp_Id  32561.0  189778.366512  105549.977697  12285.0  117827.0  178356.0
# Exp     32561.0      10.080679       2.572720      1.0       9.0      10.0
# HRA     32561.0    1077.648844    7385.292085      0.0       0.0       0.0
# TA      32561.0      87.303830     402.960219      0.0       0.0       0.0
# DA      32561.0      40.437456      12.347429      1.0      40.0      40.0
#
#              75%        max
# Sr.No.      48.0       90.0
# Emp_Id  237051.0  1484705.0
# Exp         12.0       16.0
# HRA          0.0    99999.0
# TA           0.0     4356.0
# DA          45.0       99.0

# %% [markdown]
# ##### Fetch the Statistical Information of Dataframe contain All Features

# %%
df1.describe(include = 'all')
# Out:
#               Sr.No.  Job_Type        Emp_Id Education           Exp  \
# count   32561.000000     32561  3.256100e+04     32561  32561.000000
# unique           NaN         9           NaN        16           NaN
# top              NaN   Private           NaN   HS-grad           NaN
# freq             NaN     22696           NaN     10501           NaN
# mean       38.581647       NaN  1.897784e+05       NaN     10.080679
# std        13.640433       NaN  1.055500e+05       NaN      2.572720
# min        17.000000       NaN  1.228500e+04       NaN      1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN      9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN     10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN     12.000000
# max        90.000000       NaN  1.484705e+06       NaN     16.000000
#
#                      Status             Role Living_with  Colour    Sex  \
# ...

# %%
df1.describe(include = 'all').T
# Out:
#                count unique                  top   freq           mean  \
# Sr.No.       32561.0    NaN                  NaN    NaN      38.581647
# Job_Type       32561      9              Private  22696            NaN
# Emp_Id       32561.0    NaN                  NaN    NaN  189778.366512
# Education      32561     16              HS-grad  10501            NaN
# Exp          32561.0    NaN                  NaN    NaN      10.080679
# Status         32561      7   Married-civ-spouse  14976            NaN
# Role           32561     15       Prof-specialty   4140            NaN
# Living_with    32561      6              Husband  13193            NaN
# Colour         32561      5                White  27816            NaN
# Sex            32561      2                 Male  21790            NaN
# HRA          32561.0    NaN                  NaN    NaN    1077.648844
# TA           32561.0    NaN                  NaN    NaN       87.30383
# ...

# %% [markdown]
# #### Fetch the Duplicates Values From the Dataframe

# %%
df1[df1.duplicated()]
# Out:
#        Sr.No.           Job_Type  Emp_Id      Education  Exp  \
# 4881       25            Private  308144      Bachelors   13
# 5104       90            Private   52386   Some-college   10
# 9171       21            Private  250051   Some-college   10
# 11631      20            Private  107658   Some-college   10
# 13084      25            Private  195994        1st-4th    2
# 15059      21            Private  243368      Preschool    1
# 17040      46            Private  173243        HS-grad    9
# 18555      30            Private  144593        HS-grad    9
# 18698      19            Private   97261        HS-grad    9
# 21318      19            Private  138153   Some-college   10
# 21490      19            Private  146679   Some-college   10
# 21875      49            Private   31267        7th-8th    4
# 22300      25            Private  195994        1st-4th    2
# 22367      44            Private  367749      Bachelors   13
# ...

# %% [markdown]
# #### Count of Duplicated Values of Features From Dataframe

# %%
for col in df1.columns:
    dup = (df1[df1.duplicated(col).sort_values(ascending=False)])
    print(f"{col} : {len(dup)}")
# Out:
# Sr.No. : 32488
# Job_Type : 32552
# Emp_Id : 10913
# Education : 32545
# Exp : 32545
# Status : 32554
# Role : 32546
# Living_with : 32555
# Colour : 32556
# Sex : 32559
# HRA : 32442
# TA : 32469
# DA : 32467
# Country : 32519
# Salary : 32559

# %%
df1.isna().sum()
# Out:
# Sr.No.         0
# Job_Type       0
# Emp_Id         0
# Education      0
# Exp            0
# Status         0
# Role           0
# Living_with    0
# Colour         0
# Sex            0
# HRA            0
# TA             0
# DA             0
# Country        0
# Salary         0
# dtype: int64

# %% [markdown]
# #### Fetch the Duplicates Values of `Living_with` Feature of Dataframe

# %%
df1[df1.duplicated("Living_with")]
# Out:
#        Sr.No.           Job_Type  Emp_Id    Education  Exp  \
# 2          38            Private  215646      HS-grad    9
# 3          53            Private  234721         11th    7
# 5          37            Private  284582      Masters   14
# 6          49            Private  160187          9th    5
# 7          52   Self-emp-not-inc  209642      HS-grad    9
# ...       ...                ...     ...          ...  ...
# 32556      27            Private  257302   Assoc-acdm   12
# 32557      40            Private  154374      HS-grad    9
# 32558      58            Private  151910      HS-grad    9
# 32559      22            Private  201490      HS-grad    9
# 32560      52       Self-emp-inc  287927      HS-grad    9
#
#                        Status                Role     Living_with  Colour  \
# 2                    Divorced   Handlers-cleaners   Not-in-family   White
# 3          Married-civ-spouse   Handlers-cleaners         Husband   Black
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       32561 non-null  int64
#  1   Job_Type     32561 non-null  object
#  2   Emp_Id       32561 non-null  int64
#  3   Education    32561 non-null  object
#  4   Exp          32561 non-null  int64
#  5   Status       32561 non-null  object
#  6   Role         32561 non-null  object
#  7   Living_with  32561 non-null  object
#  8   Colour       32561 non-null  object
#  9   Sex          32561 non-null  object
#  10  HRA          32561 non-null  int64
#  11  TA           32561 non-null  int64
#  12  DA           32561 non-null  int64
#  13  Country      32561 non-null  object
#  14  Salary       32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
fea_col = [col for col in df1.columns if df1[col].dtype == "O"]

# %%
df1[fea_col]
# Out:
#                 Job_Type    Education               Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                      Role     Living_with  Colour      Sex         Country  \
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
for col in df1[fea_col]:
    df1[col] = df1[col].apply(lambda x : x.lstrip())

# %% [markdown]
# #### Fetch the Unique Values of `Job_Type` Feature of Dataframe

# %%
df1['Job_Type'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %% [markdown]
# #### Replace Character `?` with `nan` values in the `Job_Type` Feature of Dataframe

# %%
df1['Job_Type'] = df1['Job_Type'].str.replace('?',"")

# %%
df1['Job_Type'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %% [markdown]
# #### Replace Character `?` with `nan` values in the `Role` Feature of Dataframe

# %%
df1['Role'] = df1['Role'].str.replace("?", "")

# %%
df1.Role.unique()
# Out:
# array(['Adm-clerical', 'Exec-managerial', 'Handlers-cleaners',
#        'Prof-specialty', 'Other-service', 'Sales', 'Craft-repair',
#        'Transport-moving', 'Farming-fishing', 'Machine-op-inspct',
#        'Tech-support', '', 'Protective-serv', 'Armed-Forces',
#        'Priv-house-serv'], dtype=object)

# %%
df1.Country = df1['Country'].str.replace('?', "")

# %%
df1.Country.unique()
# Out:
# array(['United-States', 'Cuba', 'Jamaica', 'India', '', 'Mexico', 'South',
#        'Puerto-Rico', 'Honduras', 'England', 'Canada', 'Germany', 'Iran',
#        'Philippines', 'Italy', 'Poland', 'Columbia', 'Cambodia',
#        'Thailand', 'Ecuador', 'Laos', 'Taiwan', 'Haiti', 'Portugal',
#        'Dominican-Republic', 'El-Salvador', 'France', 'Guatemala',
#        'China', 'Japan', 'Yugoslavia', 'Peru',
#        'Outlying-US(Guam-USVI-etc)', 'Scotland', 'Trinadad&Tobago',
#        'Greece', 'Nicaragua', 'Vietnam', 'Hong', 'Ireland', 'Hungary',
#        'Holand-Netherlands'], dtype=object)

# %%
df1['Salary'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %% [markdown]
# #### To check the Missing Values/Null Values From Dataframe

# %%
df1.isna().sum()
# Out:
# Sr.No.         0
# Job_Type       0
# Emp_Id         0
# Education      0
# Exp            0
# Status         0
# Role           0
# Living_with    0
# Colour         0
# Sex            0
# HRA            0
# TA             0
# DA             0
# Country        0
# Salary         0
# dtype: int64

# %% [markdown]
# #### To check value counts of Category in `Job_Type` column of Dataframe

# %%
df1['Job_Type'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
#                      1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: Job_Type, dtype: int64

# %% [markdown]
# #### To check Percentage of Value Counts of `Job_Type` column

# %%
df1['Job_Type'].value_counts(normalize = True).sort_values(ascending = False)*100
# Out:
# Private             69.703019
# Self-emp-not-inc     7.803814
# Local-gov            6.427935
#                      5.638647
# State-gov            3.986364
# Self-emp-inc         3.427413
# Federal-gov          2.948312
# Without-pay          0.042996
# Never-worked         0.021498
# Name: Job_Type, dtype: float64

# %% [markdown]
# #### To Check Percentage of Value_Counts of Category_Features of Dataframe

# %%
fea_col = [col for col in df1.columns if df1[col].dtype == "O" ]
for col in df1[fea_col]:
    print(f"{col} : {df1[col].value_counts(normalize = True)*100}")
    print("*" * 90)
# Out:
# Job_Type : Private             69.703019
# Self-emp-not-inc     7.803814
# Local-gov            6.427935
#                      5.638647
# State-gov            3.986364
# Self-emp-inc         3.427413
# Federal-gov          2.948312
# Without-pay          0.042996
# Never-worked         0.021498
# Name: Job_Type, dtype: float64
# ******************************************************************************************
# Education : HS-grad         32.250238
# Some-college    22.391818
# Bachelors       16.446055
# Masters          5.291607
# Assoc-voc        4.244341
# 11th             3.608612
# Assoc-acdm       3.276926
# 10th             2.865391
# 7th-8th          1.983969
# Prof-school      1.768987
# 9th              1.578576
# 12th             1.329812
# Doctorate        1.268389
# 5th-6th          1.022696
# 1st-4th          0.515955
# Preschool        0.156629
# Name: Education, dtype: float64
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
sns.countplot(df1['Job_Type'], palette="Set1_r")
plt.xticks(size=15, rotation=90)
plt.show()

# %%
plt.figure(figsize=(30,30))
for i in range(0, len(fea_col)):
    plt.subplot(3, 3, i+1)
    sns.countplot(x = df1[fea_col[i]], data = df1[fea_col], palette = 'Set1_r')
    plt.xticks(rotation=90)
    plt.xlabel(fea_col[i])
    plt.title("Countplots")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### To Fetch Only Numerical Features From Dataframe

# %%
num_col = [col for col in df1.columns if df1[col].dtype != "O" ]
num_col
# Out:
# ['Sr.No.', 'Emp_Id', 'Exp', 'HRA', 'TA', 'DA']

# %% [markdown]
# ### Plot Countplots of Numerical Features of Dataframe

# %%
num_col1 = ['Exp', 'HRA', 'TA', 'DA']
plt.figure(figsize=(40,30))
plt.suptitle("Univariate Analysis of Numerical Features")
for i in range(0, len(num_col1)):
    plt.subplot(2,2, i+1)
    sns.countplot(x = df1[num_col1[i]], data = df1[num_col1], palette = 'Set1_r')
    plt.xticks(rotation=90)
    plt.xlabel(num_col1[i])
    
plt.tight_layout()
plt.show()

# %%
df1[num_col]
# Out:
#        Sr.No.  Emp_Id  Exp    HRA  TA  DA
# 0          39   77516   13   2174   0  40
# 1          50   83311   13      0   0  13
# 2          38  215646    9      0   0  40
# 3          53  234721    7      0   0  40
# 4          28  338409   13      0   0  40
# ...       ...     ...  ...    ...  ..  ..
# 32556      27  257302   12      0   0  38
# 32557      40  154374    9      0   0  40
# 32558      58  151910    9      0   0  40
# 32559      22  201490    9      0   0  20
# 32560      52  287927    9  15024   0  40
#
# [32561 rows x 6 columns]

# %%
plt.hist(df1['Exp'])
# Out:
# (array([  219.,   333.,  1160.,   933.,  1608., 10501.,  8673.,  1067.,
#          7078.,   989.]),
#  array([ 1. ,  2.5,  4. ,  5.5,  7. ,  8.5, 10. , 11.5, 13. , 14.5, 16. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Plot Histograms of Numerical Features of Dataframe

# %%
num_col1 = ['Exp', 'HRA', 'TA', 'DA']
plt.figure(figsize=(25, 15))
plt.suptitle("Univariate Analysis of Numerical Features")
for i in range(0, len(num_col1)):
    plt.subplot(2,2, i+1)
    plt.hist(x = df1[num_col1[i]])
    plt.xticks(rotation=90)
    plt.xlabel(num_col1[i], size = 15)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot Distplots of Numerical Features of Dataframe

# %%
num_col1 = ['Exp', 'HRA', 'TA', 'DA']
plt.figure(figsize=(25, 15))
plt.suptitle("Univariate Analysis of Numerical Features")
for i in range(0, len(num_col1)):
    plt.subplot(2,2, i+1)
    sns.distplot(x = df1[num_col1[i]], kde = True, color = 'red')
    plt.xticks(rotation=90)
    plt.xlabel(num_col1[i], size = 15)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot kdeplots of Numerical Features of Dataframe

# %%
num_col1 = ['Exp', 'HRA', 'TA', 'DA']
plt.figure(figsize=(25, 15))
plt.suptitle("Univariate Analysis of Numerical Features")
for i in range(0, len(num_col1)):
    plt.subplot(2,2, i+1)
    sns.kdeplot(x = df1[num_col1[i]], shade = True, color = 'red')
    plt.xticks(rotation=90)
    plt.xlabel(num_col1[i], size = 15)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plot piecharts of Numerical Features of Dataframe

# %%
fea_col
# Out:
# ['Job_Type',
#  'Education',
#  'Status',
#  'Role',
#  'Living_with',
#  'Colour',
#  'Sex',
#  'Country',
#  'Salary']

# %%
df1['Job_Type'].value_counts().plot.pie(figsize=(15,15), autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Job_Type'>

# %%
plt.figure(figsize=(40,40))
plt.suptitle("Pie Chart of Categorical Features of Dataframe", fontsize = 25, fontweight='bold')
for i in range(0, len(fea_col)):
    plt.subplot(3,3, i+1)
    df1[fea_col[i]].value_counts().plot.pie(figsize=(25,25),autopct="%1.1f%%")
plt.tight_layout()
plt.show()

# %%
df1_job_cat = df1['Job_Type'].value_counts().head(10)
df1_job_cat
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
#                      1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: Job_Type, dtype: int64

# %% [markdown]
# #### Convert the `Job_Type` Series into Dataframe

# %%
df1_job_cat_df = pd.DataFrame(df1['Job_Type'].value_counts())
df1_job_cat_df
# Out:
#                   Job_Type
# Private              22696
# Self-emp-not-inc      2541
# Local-gov             2093
#                       1836
# State-gov             1298
# Self-emp-inc          1116
# Federal-gov            960
# Without-pay             14
# Never-worked             7

# %% [markdown]
# #### To change the name of column `Job_Type` to `Count`

# %%
df1_job_cat_df.rename(columns = {'Job_Type' : "Count"}, inplace = True)
df1_job_cat_df
# Out:
#                   Count
# Private           22696
# Self-emp-not-inc   2541
# Local-gov          2093
#                    1836
# State-gov          1298
# Self-emp-inc       1116
# Federal-gov         960
# Without-pay          14
# Never-worked          7

# %% [markdown]
# #### Plot the barplots

# %%
plt.figure(figsize=(15,6))
plt.suptitle("Univariate Analysis of Job_Type Features of Dataframe",fontsize = 20, fontweight='bold')
sns.barplot(x=df1_job_cat, y = 'Count', data = df1_job_cat_df[:10], palette = "Set1_r")
plt.title("Top Ten Job_Type Categories")

plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df1.head()
# Out:
#    Sr.No.          Job_Type  Emp_Id  Education  Exp              Status  \
# 0      39         State-gov   77516  Bachelors   13       Never-married
# 1      50  Self-emp-not-inc   83311  Bachelors   13  Married-civ-spouse
# 2      38           Private  215646    HS-grad    9            Divorced
# 3      53           Private  234721       11th    7  Married-civ-spouse
# 4      28           Private  338409  Bachelors   13  Married-civ-spouse
#
#                 Role    Living_with Colour     Sex   HRA  TA  DA  \
# 0       Adm-clerical  Not-in-family  White    Male  2174   0  40
# 1    Exec-managerial        Husband  White    Male     0   0  13
# 2  Handlers-cleaners  Not-in-family  White    Male     0   0  40
# 3  Handlers-cleaners        Husband  Black    Male     0   0  40
# 4     Prof-specialty           Wife  Black  Female     0   0  40
#
#          Country Salary
# 0  United-States  <=50K
# 1  United-States  <=50K
# 2  United-States  <=50K
# 3  United-States  <=50K
# ...

# %% [markdown]
# #### Which `Job_Type` having Largest No. of Exp?

# %%
df1_job_exp = df1.groupby(['Job_Type'])['Exp'].sum().sort_values(ascending=False).reset_index()
df1_job_exp
# Out:
#            Job_Type     Exp
# 0           Private  224230
# 1  Self-emp-not-inc   25985
# 2         Local-gov   23111
# 3                     17002
# 4         State-gov   14766
# 5      Self-emp-inc   12429
# 6       Federal-gov   10535
# 7       Without-pay     127
# 8      Never-worked      52

# %% [markdown]
# ##### Fetch Only First 10 Records Frome the Above DataFrame

# %%
df2_job_exp = df1_job_exp.head(10)
df2_job_exp
# Out:
#            Job_Type     Exp
# 0           Private  224230
# 1  Self-emp-not-inc   25985
# 2         Local-gov   23111
# 3                     17002
# 4         State-gov   14766
# 5      Self-emp-inc   12429
# 6       Federal-gov   10535
# 7       Without-pay     127
# 8      Never-worked      52

# %% [markdown]
# #### Plot the barplot

# %%
sns.barplot(x='Exp', y = 'Job_Type', data = df2_job_exp)
# Out:
# <AxesSubplot: xlabel='Exp', ylabel='Job_Type'>

# %%
plt.figure(figsize=(15,10))
sns.set_context("talk")
sns.set_style("darkgrid")
ax = sns.barplot(x = "Exp", y = 'Job_Type', data = df2_job_exp)
ax.set_xlabel("No. of Experience in Years")
ax.set_ylabel("Job_Type")
ax.set_title("Most Popular Job_Type", size = 20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### What are the Top Five Most Experience Job_Type ?

# %%
dje = df1.groupby(['Job_Type', 'Education'])['HRA'].sum().sort_values(ascending=False).reset_index()
dje
# Out:
#          Job_Type     Education      HRA
# 0         Private     Bachelors  5986789
# 1         Private       HS-grad  3512854
# 2         Private  Some-college  2619106
# 3         Private       Masters  2604542
# 4         Private   Prof-school  2466799
# ..            ...           ...      ...
# 112   Federal-gov       5th-6th        0
# 113   Federal-gov          12th        0
# 114  Never-worked       HS-grad        0
# 115                   Preschool        0
# 116   Without-pay  Some-college        0
#
# [117 rows x 3 columns]

# %%
dje['Job_Type'].unique()
# Out:
# array(['Private', 'Self-emp-not-inc', 'Local-gov', '', 'Self-emp-inc',
#        'State-gov', 'Federal-gov', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
dje[dje['Job_Type'] == 'Private'][:5]
# Out:
#   Job_Type     Education      HRA
# 0  Private     Bachelors  5986789
# 1  Private       HS-grad  3512854
# 2  Private  Some-college  2619106
# 3  Private       Masters  2604542
# 4  Private   Prof-school  2466799

# %%
dje[dje['Job_Type'] == 'Self-emp-not-inc'][:5]
# Out:
#             Job_Type     Education      HRA
# 7   Self-emp-not-inc   Prof-school  1361080
# 8   Self-emp-not-inc       HS-grad  1237841
# 10  Self-emp-not-inc     Bachelors   805742
# 14  Self-emp-not-inc  Some-college   537928
# 17  Self-emp-not-inc       Masters   468422

# %%
dje[dje['Job_Type'] == 'Local-gov'][:5]
# Out:
#      Job_Type     Education     HRA
# 13  Local-gov     Bachelors  597736
# 18  Local-gov       Masters  420794
# 22  Local-gov       HS-grad  264181
# 27  Local-gov  Some-college  187172
# 35  Local-gov    Assoc-acdm  129463

# %%
dje[dje['Job_Type'] == 'Self-emp-inc'][:5]
# Out:
#         Job_Type    Education      HRA
# 5   Self-emp-inc  Prof-school  1804369
# 6   Self-emp-inc    Bachelors  1379870
# 12  Self-emp-inc      HS-grad   725794
# 15  Self-emp-inc      Masters   516676
# 16  Self-emp-inc    Doctorate   479555

# %%
dje[dje['Job_Type'] == 'State-gov'][:5]
# Out:
#      Job_Type    Education     HRA
# 24  State-gov      Masters  232080
# 25  State-gov    Bachelors  216691
# 34  State-gov    Doctorate  138882
# 37  State-gov  Prof-school  122870
# 38  State-gov      HS-grad  106086

# %%
job_types = ['Private', 'Self-emp-not-inc', 'Local-gov', 'Self-emp-inc','State-gov']
sns.set_context("poster")
sns.set_style("darkgrid")
plt.figure(figsize=(40,30))
for i, job in enumerate(job_types):
    df3 = dje[dje['Job_Type'] == job].head()
    plt.subplot(4,2, i+1)
    sns.barplot(x = "HRA", y = "Job_Type", data = df3)
    plt.xlabel("Experience in Years")
    plt.ylabel("")
plt.tight_layout()
plt.subplots_adjust(hspace = .3)
plt.show()

# %% [markdown]
# ### How many Job_Type which have max HRA?

# %%
df1.groupby(['Job_Type'])['HRA'].sum().reset_index()
# Out:
#            Job_Type       HRA
# 0                     1114077
# 1       Federal-gov    799903
# 2         Local-gov   1842264
# 3      Never-worked         0
# 4           Private  20181687
# 5      Self-emp-inc   5441274
# 6  Self-emp-not-inc   4792483
# 7         State-gov    910806
# 8       Without-pay      6830

# %%
max_hra = df1.groupby(['Job_Type'])['HRA'].sum().sort_values(ascending=False).reset_index()
max_hra
# Out:
#            Job_Type       HRA
# 0           Private  20181687
# 1      Self-emp-inc   5441274
# 2  Self-emp-not-inc   4792483
# 3         Local-gov   1842264
# 4                     1114077
# 5         State-gov    910806
# 6       Federal-gov    799903
# 7       Without-pay      6830
# 8      Never-worked         0

# %% [markdown]
# ##### Fetch the records whose max HRA

# %%
max_hra.head()
# Out:
#            Job_Type       HRA
# 0           Private  20181687
# 1      Self-emp-inc   5441274
# 2  Self-emp-not-inc   4792483
# 3         Local-gov   1842264
# 4                     1114077

# %% [markdown]
# #### How many `Job_Type, Emp_Id, Education` which have maximum HRA?

# %%
max_hra1 = df1.groupby(["Job_Type", "Emp_Id", "Education"])['HRA'].sum().sort_values(ascending=False).reset_index()
max_hra1
# Out:
#                Job_Type  Emp_Id     Education     HRA
# 0               Private  102308       Masters  115023
# 1               Private  118798       HS-grad   99999
# 2      Self-emp-not-inc  401118       HS-grad   99999
# 3               Private   28419   Prof-school   99999
# 4      Self-emp-not-inc   95280  Some-college   99999
# ...                 ...     ...           ...     ...
# 30324           Private  128272       HS-grad       0
# 30325           Private  128272           9th       0
# 30326           Private  128230       HS-grad       0
# 30327           Private  128230       7th-8th       0
# 30328       Without-pay  344858       HS-grad       0
#
# [30329 rows x 4 columns]

# %% [markdown]
# #### Plot scatterplot between `HRA` and `Job_Type` of DataFrame

# %%
plt.figure(figsize=(20,15))
sns.scatterplot(data = df1, x = 'HRA', y = 'Job_Type')
plt.show()

# %% [markdown]
# #### Plot pie chart

# %%
df1['Job_Type'].value_counts().plot.pie(y = 'Job_Type', legend = False, figsize=(15,15),autopct = "%1.1f%%")
# Out:
# <AxesSubplot: ylabel='Job_Type'>

# %%
df1['Salary'].value_counts().plot.pie(y = 'Job_Type', legend = False, figsize=(5,5),autopct = "%1.1f%%")
# Out:
# <AxesSubplot: ylabel='Salary'>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sr.No.       32561 non-null  int64
#  1   Job_Type     32561 non-null  object
#  2   Emp_Id       32561 non-null  int64
#  3   Education    32561 non-null  object
#  4   Exp          32561 non-null  int64
#  5   Status       32561 non-null  object
#  6   Role         32561 non-null  object
#  7   Living_with  32561 non-null  object
#  8   Colour       32561 non-null  object
#  9   Sex          32561 non-null  object
#  10  HRA          32561 non-null  int64
#  11  TA           32561 non-null  int64
#  12  DA           32561 non-null  int64
#  13  Country      32561 non-null  object
#  14  Salary       32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# #### Boxplot--Bivariate Analysis -- Which is Applicable for Any Variables

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x = "Exp", y = "Job_Type", data = df1)
plt.xticks(size=15, rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(y = "Exp", x = "Job_Type", data = df1)
plt.xticks(size=15, rotation=90)
plt.show()

# %% [markdown]
# #### Which Job_Type are of Largest HRA?

# %%
djh = df1.groupby(['Job_Type'])['HRA'].max().sort_values(ascending=False).reset_index()
djh
# Out:
#            Job_Type    HRA
# 0                    99999
# 1       Federal-gov  99999
# 2         Local-gov  99999
# 3           Private  99999
# 4      Self-emp-inc  99999
# 5  Self-emp-not-inc  99999
# 6         State-gov  99999
# 7       Without-pay   4416
# 8      Never-worked      0

# %% [markdown]
# #### Plot Barplot Between `Job_Type` and `HRA` of Dataframe

# %%
plt.figure(figsize=(8,7))
sns.barplot(x='Job_Type', y ='HRA', data = djh)
plt.xticks(size=15, rotation=90)
plt.show()

# %% [markdown]
# ### Pairplot

# %%
plt.figure(figsize=(20,20))
sns.pairplot(df1)
plt.show()

# %% [markdown]
# ### Plot Countplot

# %%
columns = ['Job_Type', 'Education', 'Exp', 'Status', 'Role',
       'Living_with', 'Colour', 'Sex', 'DA', 'Salary']

# %%
plt.figure(figsize=(30,30))
for i in range(0, len(columns)):
    plt.subplot(4,4, i+1)
    sns.countplot(x = df1[columns[i]], data = df1[columns], palette = "Set1_r")
    plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
